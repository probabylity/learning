# %% [markdown]
# Ссылка на датасет: https://drive.google.com/file/d/1r0zXYIG7_lz-PtT1QeGEEWyuzFkp5b5V/view?usp=sharing
#
# Источник: https://www.kaggle.com/datasets/arashnic/hr-analytics-job-change-of-data-scientists

# %%
! gdown --id 1r0zXYIG7_lz-PtT1QeGEEWyuzFkp5b5V
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1r0zXYIG7_lz-PtT1QeGEEWyuzFkp5b5V
# To: /content/HR_analytics.zip
# 100% 302k/302k [00:00<00:00, 84.2MB/s]

# %%
! unzip /content/HR_analytics.zip
# Out:
# Archive:  /content/HR_analytics.zip
#   inflating: aug_test.csv
#   inflating: aug_train.csv
#   inflating: sample_submission.csv

# %% [markdown]
# # Чтение данных

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/aug_train.csv')

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# # Основные операции с датафреймом

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %%
df[['city','city_development_index']]
# Out:
#            city  city_development_index
# 0      city_103                   0.920
# 1       city_40                   0.776
# 2       city_21                   0.624
# 3      city_115                   0.789
# 4      city_162                   0.767
# ...         ...                     ...
# 19153  city_173                   0.878
# 19154  city_103                   0.920
# 19155  city_103                   0.920
# 19156   city_65                   0.802
# 19157   city_67                   0.855
#
# [19158 rows x 2 columns]

# %%
df[(df['city'] == 'city_40')&(df['gender'] == 'Male')]
# Out:
#        enrollee_id     city  city_development_index gender  \
# 1            29725  city_40                   0.776   Male
# 23            7041  city_40                   0.776   Male
# 363          28229  city_40                   0.776   Male
# 461          18620  city_40                   0.776   Male
# 827           1783  city_40                   0.776   Male
# 998          29671  city_40                   0.776   Male
# 2916         21646  city_40                   0.776   Male
# 3636         10085  city_40                   0.776   Male
# 4251          2603  city_40                   0.776   Male
# 4346          4051  city_40                   0.776   Male
# 4526         11840  city_40                   0.776   Male
# 4588          7010  city_40                   0.776   Male
# 5156          7556  city_40                   0.776   Male
# 6330          5389  city_40                   0.776   Male
# 6483           484  city_40                   0.776   Male
# ...

# %% [markdown]
# # Пропуски

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df.isna().mean().sort_values(ascending=False)
# Out:
# company_type              0.320493
# company_size              0.309949
# gender                    0.235306
# major_discipline          0.146832
# education_level           0.024011
# last_new_job              0.022080
# enrolled_university       0.020148
# experience                0.003393
# enrollee_id               0.000000
# city                      0.000000
# city_development_index    0.000000
# relevent_experience       0.000000
# training_hours            0.000000
# target                    0.000000
# dtype: float64

# %% [markdown]
# # Типы переменных

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
import matplotlib.pyplot as plt


plt.style.use('dark_background')

# %%
df['city_development_index'].hist()

# %%
df['city_development_index'].describe()
# Out:
# count    19158.000000
# mean         0.828848
# std          0.123362
# min          0.448000
# 25%          0.740000
# 50%          0.903000
# 75%          0.920000
# max          0.949000
# Name: city_development_index, dtype: float64

# %%
df['gender'].value_counts(dropna=False)
# Out:
# Male      13221
# NaN        4508
# Female     1238
# Other       191
# Name: gender, dtype: int64

# %% [markdown]
# # Фильтрация по квантилю

# %%
q = df['city_development_index'].quantile(0.25)

# %%
q
# Out:
# 0.74

# %%
df[df['city_development_index'] < q]
# Out:
#        enrollee_id      city  city_development_index gender  \
# 2            11561   city_21                   0.624    NaN
# 10           29452   city_21                   0.624    NaN
# 13            5826   city_21                   0.624   Male
# 14            8722   city_21                   0.624    NaN
# 17            5764   city_21                   0.624    NaN
# ...            ...       ...                     ...    ...
# 19144        17191   city_21                   0.624    NaN
# 19145          155   city_44                   0.725    NaN
# 19147        21319   city_21                   0.624   Male
# 19148         9212   city_21                   0.624    NaN
# 19151        11385  city_149                   0.689   Male
#
#            relevent_experience enrolled_university education_level  \
# 2       No relevent experience    Full time course        Graduate
# 10      No relevent experience    Full time course     High School
# ...

# %%
df[df['city_development_index'] >= q]['city_development_index'].hist()

# %% [markdown]
# # Сводники

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df['target'].mean()
# Out:
# 0.24934753105752167

# %%
df.groupby('gender',dropna=False)['target'].agg(['count','mean'])
# Out:
#         count      mean
# gender
# Female   1238  0.263328
# Male    13221  0.227819
# Other     191  0.261780
# NaN      4508  0.308119

# %%
df.groupby('education_level',dropna=False)['target'].agg(['count','mean'])
# Out:
#                  count      mean
# education_level
# Graduate         11598  0.279790
# High School       2017  0.195340
# Masters           4361  0.214400
# Phd                414  0.140097
# Primary School     308  0.133117
# NaN                460  0.226087

# %%
df.groupby('education_level',dropna=False)['target'].mean().plot(kind='bar')

# %% [markdown]
# # Сводники для непрерывных переменных

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df['city_development_group'] = pd.cut(df['city_development_index'],5)

# %%
df.groupby('city_development_group',dropna=False)['target'].agg(['count','mean'])
# Out:
#                         count      mean
# city_development_group
# (0.447, 0.548]            178  0.578652
# (0.548, 0.648]           3297  0.582651
# (0.648, 0.749]           1529  0.273381
# (0.749, 0.849]           1949  0.194459
# (0.849, 0.949]          12205  0.160262

# %%
df['city_development_index'].hist()

# %%
df['city_development_group_q'] = pd.qcut(df['city_development_index'],5,duplicates='drop')

# %%
t = df.groupby('city_development_group_q',dropna=False)['target'].agg(['count','mean'])

# %%
t['mean'].plot()

# %%
df['city_development_group_custom'] = pd.cut(df['city_development_index'],
                                             [-float('inf'),0.1,0.2,0.5,float('inf')])

# %%
df.groupby('city_development_group_custom',dropna=False)['target'].agg(['count','mean'])
# Out:
#                                count      mean
# city_development_group_custom
# (-inf, 0.1]                        0       NaN
# (0.1, 0.2]                         0       NaN
# (0.2, 0.5]                        63  0.587302
# (0.5, inf]                     19095  0.248233

# %% [markdown]
# # Группировка категориальных данных

# %%
df.groupby('education_level',dropna=False)['target'].agg(['count','mean'])
# Out:
#                  count      mean
# education_level
# Graduate         11598  0.279790
# High School       2017  0.195340
# Masters           4361  0.214400
# Phd                414  0.140097
# Primary School     308  0.133117
# NaN                460  0.226087

# %%
def education_group(x):
  if x in ['High School', 'Primary School']:
    return 'School'
  if x in ['Masters', 'Phd']:
    return 'Masters_and_phd'
  return x

# %%
df['new_educational_level'] = df['education_level'].apply(education_group)

# %%
df.groupby('new_educational_level',dropna=False)['target'].agg(['count','mean'])
# Out:
#                        count      mean
# new_educational_level
# Graduate               11598  0.279790
# Masters_and_phd         4775  0.207958
# School                  2325  0.187097
# NaN                      460  0.226087

# %% [markdown]
# # Функция с несколькими столбцами

# %%
def new_training_hours(row):
  if row['education_level'] == 'Phd':
    return row['training_hours'] + 1000
  return row['training_hours']

# %%
df['new_training_hours'] = df.apply(new_training_hours, axis=1)

# %%
df[df['education_level'] == 'Phd']
# Out:
#        enrollee_id      city  city_development_index gender  \
# 37           10164  city_114                   0.926   Male
# 121          13915   city_16                   0.910   Male
# 130           3921   city_36                   0.893    NaN
# 135          23947  city_103                   0.920    NaN
# 152          31786  city_103                   0.920   Male
# ...            ...       ...                     ...    ...
# 18738         1477  city_162                   0.767   Male
# 18800        18365  city_103                   0.920   Male
# 18807          229  city_114                   0.926   Male
# 18944         2678  city_104                   0.924    NaN
# 19044        14441   city_89                   0.925   Male
#
#            relevent_experience enrolled_university education_level  \
# 37     Has relevent experience       no_enrollment             Phd
# 121    Has relevent experience       no_enrollment             Phd
# ...

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# # Pivot Table

# %%
df.groupby('new_educational_level',dropna=False)['target'].agg(['count','mean'])
# Out:
#                        count      mean
# new_educational_level
# Graduate               11598  0.279790
# Masters_and_phd         4775  0.207958
# School                  2325  0.187097
# NaN                      460  0.226087

# %%
df['new_educational_level'] = df['new_educational_level'].fillna('no_info')

# %%
t = df.pivot_table(index='new_educational_level', values='target', aggfunc=['count','mean'])

# %%
t.reset_index()
# Out:
#   new_educational_level  count      mean
#                         target    target
# 0              Graduate  11598  0.279790
# 1       Masters_and_phd   4775  0.207958
# 2                School   2325  0.187097
# 3               no_info    460  0.226087

# %%
df.pivot_table(index='new_educational_level', columns='gender', values='target', aggfunc=['count','mean'])
# Out:
#                        count                  mean
# gender                Female  Male Other    Female      Male     Other
# new_educational_level
# Graduate                 773  8144   112  0.279431  0.257122  0.330357
# Masters_and_phd          386  3237    31  0.233161  0.186284  0.096774
# School                    71  1598    39  0.267606  0.171464  0.205128
# no_info                    8   242     9  0.125000  0.169421  0.222222

# %%
df.groupby(['new_educational_level','gender'],dropna=False)[['target','city_development_index']].agg(['count','mean']).reset_index()
# Out:
#    new_educational_level  gender target           city_development_index  \
#                                   count      mean                  count
# 0               Graduate  Female    773  0.279431                    773
# 1               Graduate    Male   8144  0.257122                   8144
# 2               Graduate   Other    112  0.330357                    112
# 3               Graduate     NaN   2569  0.349552                   2569
# 4        Masters_and_phd  Female    386  0.233161                    386
# 5        Masters_and_phd    Male   3237  0.186284                   3237
# 6        Masters_and_phd   Other     31  0.096774                     31
# 7        Masters_and_phd     NaN   1121  0.264942                   1121
# 8                 School  Female     71  0.267606                     71
# 9                 School    Male   1598  0.171464                   1598
# 10                School   Other     39  0.205128                     39
# ...

# %%
df.groupby('new_educational_level',dropna=False)['target'].agg(['count','mean'])
# Out:
#                        count      mean
# new_educational_level
# Graduate               11598  0.279790
# Masters_and_phd         4775  0.207958
# School                  2325  0.187097
# no_info                  460  0.226087
